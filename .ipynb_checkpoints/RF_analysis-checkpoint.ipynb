# %%
from qutip import basis, qeye, tensor, destroy, thermal_dm, mesolve, steadystate, Options
import matplotlib.pyplot as plt
import numpy as np
from utils import *
import phonons as RC
import optical as EM
import time


G= basis(2,0)
E = basis(2,1)

sigma = G*E.dag()

I_sys = qeye(2)
initial_sys = G*G.dag()#0.5*(E+G)*(G.dag()+E.dag())
T_EM = 0.
reload(RC)
reload(EM)

""" CHANGE THESE """
labels = [ 'OO', 'XO', 'OX', 'site_coherence', 
            'bright', 'dark', 'eig_x', 'eig_y', 'eig_z', 'eig_x_equiv', 'sigma_x', 'sigma_y', 'sigma_z',
             'RC1_position1', 'RC2_position', 
             'RC1_number', 'RC2_number']

tex_labels = [ '$\\rho_0$', '$\\rho_1$', '$\\rho_2$', '$\\rho_12$', 
            '$|+ \\rangle$', '$|- \\rangle$', '$\\tilde{\\sigma}_x$', '$\\tilde{\\sigma}_y^{\prime}$','$\\tilde{\\sigma}_z^{\prime}$', 'eig_x_equiv',
            '$\\sigma_x$', '$\\sigma_y$','$\\sigma_z$',
             r'$\hat{x_1}$', r'$\hat{x_2}$', 
             r'$\hat{N_1}$', r'$\hat{N_2}$']

# %%
def d(detuning, alpha, Rabi):
    
    detuning = detuning*ev_to_inv_cm #0.01*ev_to_inv_cm
    epsilon = 1*ev_to_inv_cm
    w_laser = epsilon + detuning
    Rabi = Rabi*ev_to_inv_cm # 0.01*ev_to_inv_cm
    T_ph = 77.
    
    w0 = 500.
    Gamma = (w0**2)/100.
    Gamma_EM =  100*5.309e-3
    alpha_ph = alpha*ev_to_inv_cm
    
    #kappa= np.sqrt(np.pi * alpha_ph * w0 / 2.)
    #shift = ((kappa**2)/w0)
    #w_laser #+= shift
    N = 3
    H_sub = (epsilon-w_laser)*sigma.dag()*sigma + (Rabi/2)*(sigma.dag()+sigma)
    print H_sub, "Laser "
    tf =  3 #0.025

    timelist = np.linspace(0, tf, 1000)

    n_RC = EM.Occupation(w0, T_ph)

    #prop_of_eps = np.linspace(0.05, upper_alpha, 3)
    

    I = qeye(N)
    print "T_ph={}".format(T_ph)
    #print "Exact solution took {} seconds.".format(time.time()-ti)
    expects = [tensor(G*G.dag(), I), 0.5*tensor(E*G.dag()+G*E.dag(), I), 0.5*(1j*tensor(E*G.dag()-G*E.dag(), I)),
               tensor(E*E.dag(), I), tensor(qeye(2), destroy(N).dag()*destroy(N)), 
               tensor(qeye(2), destroy(N).dag()+destroy(N))]

    rho_0 = tensor(initial_sys, thermal_dm(N, n_RC))

    

    L_RC, H, A_EM, A_nrwa, Z, wRC, kappa, gamma = RC.RC_function_gen(H_sub, sigma, T_ph, Gamma, w0, alpha_ph, N, 
                                                                  silent=False, w_laser=w_laser)
    eps_rot = epsilon #+((kappa**2)/wRC)
    J = J_multipolar
    L_EM = EM.L_nonsecular(H, A_EM, eps_rot, Gamma_EM, T_EM, J, silent=False, w_laser=w_laser)
    L_add = EM.L_nonsecular(tensor(H_sub, I), A_EM, eps_rot, Gamma_EM, T_EM, J, silent=False, w_laser=w_laser)
    print steadystate(H, [L_RC+L_EM]).ptrace(0), steadystate(H, [L_RC+L_add]).ptrace(0)
    print L_RC, L_EM
    #mesolve(H, rho0, tlist, c_ops=[], e_ops=[], args={}, options=None, progress_bar=None, _safe_mode=True)
    data = mesolve(H, rho_0, timelist, c_ops=[L_RC+L_EM], e_ops=expects, options = Options(nsteps=1500))
    data_add = mesolve(H, rho_0, timelist, c_ops=[L_RC+L_add], e_ops=expects, options = Options(nsteps=1500))
    print("Dynamics complete")
    return timelist, data, data_add
    
timelist, data, data_add = d(0.0, 0.003, 0.001)
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0.      4.03275]
#  [4.03275 0.     ]] Laser
# T_ph=77.0
# w_RC=500.0 | RC-res. coupling=0.80 | TLS-RC coupling=137.85 | Gamma_RC=2500.00 | alpha_ph=24.20 | N=3 |
# It took  0.109092950821  seconds to build the Non-secular RWA Liouvillian
# It took  0.0923941135406  seconds to build the Non-secular RWA Liouvillian
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.31689184+0.j         -0.03388116-0.04431715j]
#  [-0.03388116+0.04431715j  0.68310816+0.j        ]] Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.31348605+0.j         -0.03390947-0.04512108j]
#  [-0.03390947+0.04512108j  0.68651395+0.j        ]]
# Quantum object: dims = [[[2, 3], [2, 3]], [[2, 3], [2, 3]]], shape = (36, 36), type = super, isherm = False
# Qobj data =
# [[-2.17365596e-01  1.26207841e-02 -1.76791205e+03 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 5.90897837e-04 -1.25042257e+03  1.12802576e-01 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [-1.53700687e-01  1.78484841e-02 -2.50031388e+03 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  ...
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -2.36869350e+03
#   -6.76772722e+02 -1.68229362e+03]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -7.35951619e+02
#   -3.49781595e+03  2.92685633e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  1.47487748e+01
#   -9.57101162e+02 -4.75824491e+03]] Quantum object: dims = [[[2, 3], [2, 3]], [[2, 3], [2, 3]]], shape = (36, 36), type = super, isherm = False
# Qobj data =
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -2.89400688e-04
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#   -2.89400688e-04  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00 -2.89400688e-04]
#  ...
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  5.12530905e-01
#   -1.25701455e-02  2.89400688e-04]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  1.08535372e-02
#    5.06368076e-01 -1.65936882e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -5.44121447e-04
#    1.16360185e-02  5.01873358e-01]]
# Dynamics complete

# %%
plt.plot(timelist, data.expect[0], label='full')
plt.plot(timelist, data_add.expect[0], label='add.')
plt.legend()
plt.figure()

plt.plot(timelist, data.expect[1].real, label='full')
plt.plot(timelist, data_add.expect[1].real, label='add.')
plt.legend()
plt.figure()

# %%
def plot_spectra(timelist, pops, taulist, g1s, specs, freqs,
                freq_window=1000., tau_window=2., dyn_window_div = 7.):
    plt.close('all')
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    f1, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,6))
    f2, (ax3, ax4) = plt.subplots(1, 2, figsize=(14,6))
    label = ['Full', 'Naive']
    ls = ['dashed', 'solid']
    for i, spec in enumerate(specs):
        g_1  = g1s[i]
        freq = freqs[i]
        ax1.plot(timelist, pops[i],
                label=label[i], linestyle=ls[i])
        ax3.plot(taulist[0:int(len(taulist)/tau_window)],
                 g_1.real[0:int(len(taulist)/tau_window)], 
                 label=label[i], linestyle=ls[i])
        ax4.plot(taulist[0:int(len(taulist)/tau_window)],
                 g_1.imag[0:int(len(taulist)/tau_window)], 
                 label=label[i], linestyle=ls[i])
        ax2.plot(freq, spec, label=label[i], linestyle=ls[i])
    ax1.set_xlim(0,timelist[int((len(timelist)-1)/dyn_window_div)])
    ax3.set_xlim(0,taulist[int((len(taulist)-1)/dyn_window_div)])
    ax4.set_xlim(0,taulist[int((len(taulist)-1)/dyn_window_div)])
    ax1.set_xlabel(r"Time")
    ax2.set_xlabel(r"Frequency $cm^{-1}$")
    #ax2.axvline(eps, linestyle='dashed',color='k', alpha=0.4)
    if freq_window is not None:
        ax2.set_xlim(-freq_window,freq_window)

    ax1.set_ylabel(r"Excited state population")
    ax2.set_ylabel(r"Fluorescence intensity (arb. units)")
    ax3.set_ylabel(r"$Re[g_1(\tau)]$") # coherence
    ax4.set_ylabel(r"$Im[g_1(\tau)]$") # coherence
    ax3.set_xlabel(r"$\tau$")
    ax4.set_xlabel(r"$\tau$")
    ax1.legend()
    ax2.legend()
    ax3.legend()
    ax4.legend()
    plt.show()

# %%
method = 'adams'
order = 12
reload(EM)
def RF_spectrum(detuning=0., alpha=10, Rabi=1., w0=50., t_f=4., tau_f_mult=1., steps_per_tau=700.,
                steps_per_t=900, nsteps=8000, tau_f=2.):
    Gamma_EM =  1. #1*5.309e-3
    detuning = detuning*Gamma_EM #detuning*ev_to_inv_cm #0.01*ev_to_inv_cm
    epsilon = 1000. #1*ev_to_inv_cm
    w_laser = epsilon + detuning
    Rabi = Rabi*Gamma_EM #Rabi*ev_to_inv_cm # 0.01*ev_to_inv_cm
    T_ph = 77.
    #w0 = 50.
    wc = 52.
    Gamma =  25. #(w0**2)/100.
    print Gamma
    alpha_ph = alpha #alpha*ev_to_inv_cm
    
    #kappa= np.sqrt(np.pi * alpha_ph * w0 / 2.)
    #shift = ((kappa**2)/w0)
    #w_laser #+= shift
    
    
    #Rabi = Gamma_EM*Rabi #Rabi*ev_to_inv_cm # 0.01*ev_to_inv_cm
    J = J_multipolar
    
    kappa= np.sqrt(np.pi * alpha_ph * w0 / 2.)
    shift = ((kappa**2)/w0)
    #w_laser += shift
    H_sub = (epsilon-w_laser)*sigma.dag()*sigma + (Rabi/2)*(sigma.dag()+sigma)
    print H_sub, "Laser "
    n_RC = Occupation(w0, T_ph)
    
    
    #print "T_ph={}".format(T_ph)
    #print "Exact solution took {} seconds.".format(time.time()-ti)
    
    if abs(alpha)>0:
        N = 6
        I = qeye(N)
        L_RC, H, A_EM, A_nrwa, Z, wRC, kappa, gamma = RC.RC_function_gen(H_sub, sigma, T_ph, Gamma, w0, alpha_ph, N, 
                                                                  silent=False, w_laser=w_laser)
        H_add = tensor(H_sub, I)
        E_op = tensor(E*E.dag(), I) # population operator
        rho_0 = tensor(initial_sys, thermal_dm(N, n_RC))
        sigma_RC = tensor(sigma, I)
    else:
        L_RC, H, A_EM = 0, H_sub, sigma
        H_add = H_sub
        E_op = E*E.dag() # population operator
        rho_0 = initial_sys
        sigma_RC = sigma
    eps_rot = epsilon #+((kappa**2)/wRC)
    
    
    
    
    label = ['Full', 'Naive']
    L_full = -EM.L_nonsecular(H, A_EM, eps_rot, Gamma_EM, T_EM, J, silent=False, w_laser=w_laser)
    
    L_add = EM.L_nonsecular(H_add, A_EM, eps_rot, Gamma_EM, T_EM, J, silent=False, w_laser=w_laser)
    L_EM_list = [L_full]
    #final_t = end_T_mult/Gamma_EM
    #print "final t: ", final_t
    #timelist = np.linspace(0, final_t, int(T_increments*final_t))
    timelist = np.linspace(0, t_f, t_f*steps_per_t)
    options = qt.Options(nsteps=nsteps, store_states=True)
    pop_list = []
    g1_data = []
    spectrum_data = []
    freq_data = []
    
    for i, L_EM in enumerate(L_EM_list):
        print "Steadystate: ", steadystate(H, [L_RC+L_EM]).ptrace(0)
        ti = time.time()
        P = mesolve(H, rho_0, timelist, c_ops=[L_RC+L_EM], options=options).states
        pop = [((E_op*p).tr()).real for p in P]

        print "Completed initial dynamics calculations for {} in {}  seconds.".format(label[i], time.time()-ti)
        ti = time.time()
        Lambda_0 = sigma_RC*sum(P)
        del P
        
        taulist = np.linspace(0, tau_f, int(tau_f*steps_per_tau))
        Lambda_t = mesolve(H, Lambda_0, taulist, [L_RC+L_EM], options=options, progress_bar=None)

        g_1 = np.array([(sigma_RC.dag()*l).tr() for l in Lambda_t.states])
        g_1/=abs(g_1[0])

        spec = sp.fftpack.fft(g_1)
        dt = taulist[1]-taulist[0]
        freq = 2 * pi * np.array(sp.fftpack.fftfreq(spec.size, dt))
        spec = 2 * dt* np.real(spec)
        #freq, spec = qt.spectrum_correlation_fft(taulist, g_1) # old method
        spec-= min(spec)
        spec = spec/sum(spec)
        freq, spec = zip(*sorted(zip(freq, np.array(spec).real)))
        
        pop_list.append(pop)
        g1_data.append(g_1)
        spectrum_data.append(spec)
        freq_data.append(freq)
        print "Completed correlation function calculations for {} in {} seconds.".format(label[i], time.time()-ti)
    print "All spectra calculated."
    return timelist, pop_list, taulist, g1_data, spectrum_data, freq_data

# %%
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=0., alpha=10, Rabi=1., w0=50.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=2.)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=1000., tau_window=1., dyn_window_div=1.)
# Out:
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0.  0.5]
#  [0.5 0. ]] Laser
# w_RC=50.0 | RC-res. coupling=0.08 | TLS-RC coupling=28.02 | Gamma_RC=25.00 | alpha_ph=10.00 | N=6 |
# It took  0.473562002182  seconds to build the Non-secular RWA Liouvillian
# It took  0.207563877106  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.97798391+0.j         -0.0040627 +0.02036172j]
#  [-0.0040627 -0.02036172j  0.02201609+0.j        ]]
# Completed initial dynamics calculations for Full in 11.2269129753  seconds.
# 10.0%. Run time:   0.05s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.10s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.16s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.20s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.25s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.30s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.35s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.40s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.45s. Est. time left: 00:00:00:00
# Total run time:   0.50s
# Completed correlation function calculations for Full in 8.97989392281 seconds.
# All spectra calculated.

# %%
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=0., alpha=60, Rabi=1., w0=50.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=2.)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=250., tau_window=1., dyn_window_div=1.)
# Out:
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0.  0.5]
#  [0.5 0. ]] Laser
# w_RC=50.0 | RC-res. coupling=0.08 | TLS-RC coupling=68.65 | Gamma_RC=25.00 | alpha_ph=60.00 | N=6 |
# It took  0.461710929871  seconds to build the Non-secular RWA Liouvillian
# It took  0.217737197876  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.99548189+0.j         -0.00402731+0.00352678j]
#  [-0.00402731-0.00352678j  0.00451811+0.j        ]]
# Completed initial dynamics calculations for Full in 12.6376709938  seconds.
# Completed correlation function calculations for Full in 8.84654307365 seconds.
# All spectra calculated.

# %%
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=0., alpha=10, Rabi=1., w0=25.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=2.)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=250., tau_window=1., dyn_window_div=1.)
# Out:
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0.  0.5]
#  [0.5 0. ]] Laser
# w_RC=25.0 | RC-res. coupling=0.16 | TLS-RC coupling=19.82 | Gamma_RC=25.00 | alpha_ph=10.00 | N=6 |
# It took  0.465029001236  seconds to build the Non-secular RWA Liouvillian
# It took  0.214677095413  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.98362451+0.j         -0.00511207+0.01513313j]
#  [-0.00511207-0.01513313j  0.01637549+0.j        ]]
# Completed initial dynamics calculations for Full in 12.1388878822  seconds.
# Completed correlation function calculations for Full in 8.05388188362 seconds.
# All spectra calculated.

# %%
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=0., alpha=60, Rabi=1., w0=25.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=2.)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=250., tau_window=1., dyn_window_div=1.)
# Out:
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0.  0.5]
#  [0.5 0. ]] Laser
# w_RC=25.0 | RC-res. coupling=0.16 | TLS-RC coupling=48.54 | Gamma_RC=25.00 | alpha_ph=60.00 | N=6 |
# It took  0.421357870102  seconds to build the Non-secular RWA Liouvillian
# It took  0.201859951019  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.99623835+0.j         -0.0044644 +0.00320691j]
#  [-0.0044644 -0.00320691j  0.00376165+0.j        ]]
# Completed initial dynamics calculations for Full in 13.4982049465  seconds.
# Completed correlation function calculations for Full in 8.29998517036 seconds.
# All spectra calculated.

# %% [markdown]
# # Mollow regime

# %%
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=0., alpha=10, Rabi=20., w0=50.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=1.6)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=200., tau_window=1., dyn_window_div=1.)
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=0., alpha=60, Rabi=20., w0=50.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=1.6)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=200., tau_window=1., dyn_window_div=1.)
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=0., alpha=10, Rabi=20., w0=25.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=1.6)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=200., tau_window=1., dyn_window_div=1.)


timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=0., alpha=60, Rabi=20., w0=25.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=1.6)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=200., tau_window=1., dyn_window_div=1.)
# Out:
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0. 10.]
#  [10.  0.]] Laser
# w_RC=50.0 | RC-res. coupling=0.08 | TLS-RC coupling=28.02 | Gamma_RC=25.00 | alpha_ph=10.00 | N=6 |
# It took  0.403336048126  seconds to build the Non-secular RWA Liouvillian
# It took  0.222566843033  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.52933857+0.j         -0.086609  +0.02135692j]
#  [-0.086609  -0.02135692j  0.47066143+0.j        ]]
# Completed initial dynamics calculations for Full in 11.9107420444  seconds.
# Completed correlation function calculations for Full in 7.70428299904 seconds.
# All spectra calculated.
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0. 10.]
#  [10.  0.]] Laser
# w_RC=50.0 | RC-res. coupling=0.08 | TLS-RC coupling=68.65 | Gamma_RC=25.00 | alpha_ph=60.00 | N=6 |
# It took  0.463676929474  seconds to build the Non-secular RWA Liouvillian
# It took  0.223925113678  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.63472803+0.j         -0.07346119+0.01420677j]
#  [-0.07346119-0.01420677j  0.36527197+0.j        ]]
# Completed initial dynamics calculations for Full in 13.329351902  seconds.
# Completed correlation function calculations for Full in 8.0417330265 seconds.
# All spectra calculated.
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0. 10.]
#  [10.  0.]] Laser
# w_RC=25.0 | RC-res. coupling=0.16 | TLS-RC coupling=19.82 | Gamma_RC=25.00 | alpha_ph=10.00 | N=6 |
# It took  0.413681983948  seconds to build the Non-secular RWA Liouvillian
# It took  0.218122959137  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.55218586+0.j         -0.08371705+0.02042897j]
#  [-0.08371705-0.02042897j  0.44781414+0.j        ]]
# Completed initial dynamics calculations for Full in 12.1080520153  seconds.
# Completed correlation function calculations for Full in 7.75958991051 seconds.
# All spectra calculated.
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0. 10.]
#  [10.  0.]] Laser
# w_RC=25.0 | RC-res. coupling=0.16 | TLS-RC coupling=48.54 | Gamma_RC=25.00 | alpha_ph=60.00 | N=6 |
# It took  0.402109146118  seconds to build the Non-secular RWA Liouvillian
# It took  0.208216905594  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.70664933+0.j         -0.07569085+0.01246527j]
#  [-0.07569085-0.01246527j  0.29335067+0.j        ]]
# Completed initial dynamics calculations for Full in 12.1456320286  seconds.
# Completed correlation function calculations for Full in 7.77612900734 seconds.
# All spectra calculated.

# %%
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=50, alpha=10, Rabi=20., w0=50.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=1.6)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=200., tau_window=1., dyn_window_div=1.)
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=50, alpha=60, Rabi=20., w0=50.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=1.6)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=200., tau_window=1., dyn_window_div=1.)
timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=50, alpha=10, Rabi=20., w0=25.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=1.6)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=200., tau_window=1., dyn_window_div=1.)


timelist, pop_list, taulist, g1_data, spectrum_data, freq_data = RF_spectrum(detuning=50, alpha=60, Rabi=20., w0=25.,
                                                                             t_f=30, steps_per_tau=500, nsteps=3000, 
                                                                             tau_f=1.6)
plot_spectra(timelist, pop_list, taulist, g1_data, spectrum_data, freq_data,
                freq_window=200., tau_window=1., dyn_window_div=1.)
# Out:
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[  0.  10.]
#  [ 10. -50.]] Laser
# w_RC=50.0 | RC-res. coupling=0.08 | TLS-RC coupling=28.02 | Gamma_RC=25.00 | alpha_ph=10.00 | N=6 |
# It took  0.460412025452  seconds to build the Non-secular RWA Liouvillian
# It took  0.221212863922  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.40143675+0.j         -0.04040244+0.02860469j]
#  [-0.04040244-0.02860469j  0.59856325+0.j        ]]
# Completed initial dynamics calculations for Full in 12.2489109039  seconds.
# Completed correlation function calculations for Full in 8.62295508385 seconds.
# All spectra calculated.
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[  0.  10.]
#  [ 10. -50.]] Laser
# w_RC=50.0 | RC-res. coupling=0.08 | TLS-RC coupling=68.65 | Gamma_RC=25.00 | alpha_ph=60.00 | N=6 |
# It took  0.478358983994  seconds to build the Non-secular RWA Liouvillian
# It took  0.226276874542  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.44763848+0.j        -0.06049992+0.0226746j]
#  [-0.06049992-0.0226746j  0.55236152+0.j       ]]
# Completed initial dynamics calculations for Full in 14.2100279331  seconds.
# Completed correlation function calculations for Full in 9.07979607582 seconds.
# All spectra calculated.
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[  0.  10.]
#  [ 10. -50.]] Laser
# w_RC=25.0 | RC-res. coupling=0.16 | TLS-RC coupling=19.82 | Gamma_RC=25.00 | alpha_ph=10.00 | N=6 |
# It took  0.462306022644  seconds to build the Non-secular RWA Liouvillian
# It took  0.221597909927  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.45408069+0.j         -0.02021569+0.02678793j]
#  [-0.02021569-0.02678793j  0.54591931+0.j        ]]
# Completed initial dynamics calculations for Full in 13.1921150684  seconds.
# Completed correlation function calculations for Full in 8.52409696579 seconds.
# All spectra calculated.
# 25.0
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[  0.  10.]
#  [ 10. -50.]] Laser
# w_RC=25.0 | RC-res. coupling=0.16 | TLS-RC coupling=48.54 | Gamma_RC=25.00 | alpha_ph=60.00 | N=6 |
# It took  0.453387022018  seconds to build the Non-secular RWA Liouvillian
# It took  0.217938899994  seconds to build the Non-secular RWA Liouvillian
# Steadystate:  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.54646886+0.j         -0.06106285+0.02091363j]
#  [-0.06106285-0.02091363j  0.45353114+0.j        ]]
# Completed initial dynamics calculations for Full in 13.0287079811  seconds.
# Completed correlation function calculations for Full in 8.44068813324 seconds.
# All spectra calculated.
